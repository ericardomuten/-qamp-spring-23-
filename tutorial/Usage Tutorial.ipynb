# %%
from IPython.display import clear_output
# !pip install qiskit
# !pip install pylatexenc
clear_output()

# %%
import sys

# Append the path to the folder ../qamp-spring-2023 so we can import the package
sys.path.append('/content/drive/MyDrive/Projects/QAMP Spring 2023/qamp-spring-23')

# %%
from data_reuploading import DataReuploading

# %% [markdown]
# Defining the number of qubits, layers, and features (the dimension of input data).

# %%
DRC = DataReuploading(num_qubits=3, num_features=3, num_layers=2)
DRC.circuit.draw('mpl')

# %% [markdown]
# Adding barriers.

# %%
DRC = DataReuploading(num_qubits=4, num_features=5, num_layers=3, insert_barriers=True)
DRC.circuit.draw('mpl')

# %% [markdown]
# Changing the entanglement gate.

# %%
DRC = DataReuploading(num_qubits=2, num_features=4, num_layers=2, insert_barriers=True, entanglement_blocks='cx')
DRC.circuit.draw('mpl')

# %% [markdown]
# Changing the entanglement strategy.

# %%
DRC = DataReuploading(num_qubits=3, num_features=3, num_layers=2, insert_barriers=True, entanglement='full')
DRC.circuit.draw('mpl')

# %% [markdown]
# Example for 1-qubit circuit. The `entanglement` and `entanglement_blocks` don't matter as there will be no entanglement gate for it.

# %%
DRC = DataReuploading(num_qubits=1, num_features=3, num_layers=2, insert_barriers=True, entanglement='full', entanglement_blocks='cx')
DRC.circuit.draw('mpl')
